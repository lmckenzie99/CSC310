# %%
# !pip3 install decision-tree-id-fork # installs ID3
# Out:
# Requirement already satisfied: decision-tree-id-fork in /usr/local/lib/python3.12/dist-packages (0.0.15)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from decision-tree-id-fork) (2.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from decision-tree-id-fork) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from decision-tree-id-fork) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->decision-tree-id-fork) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->decision-tree-id-fork) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->decision-tree-id-fork) (3.6.0)

# %%
import pandas as pd
import id3                  # Id3Estimator, export_text
from sklearn import tree    # DecisionTreeClassifier, export_text
from sklearn import metrics # accuracy_score
from sklearn.tree import plot_tree # plot tree
import matplotlib.pyplot as plt # graphics visualization

# %%
tennis_df = pd.read_csv(home+"tennis.csv")
tennis_df.head()
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes

# %%
X = tennis_df.drop(columns=['play']) # features
y = tennis_df[['play']]              # target

# %%
# id3 obj
tennis_tree = id3.Id3Estimator()

# train the id3 model
tennis_tree.fit(X, y['play'])
# Out:
# Id3Estimator()

# %%
print(id3.export_text(tennis_tree.tree_,
                      feature_names=list(X.columns)))
# Out:
# outlook overcast: yes (4)
# outlook rainy
# |   windy <=0.50: yes (3)
# |   windy >0.50: no (2)
# outlook sunny
# |   humidity high: no (3)
# |   humidity normal: yes (2)

# %%
predict_df = pd.DataFrame(tennis_tree.predict(X),
                          columns=['predicted'])
predict_df
# Out:
#    predicted
# 0         no
# 1         no
# 2        yes
# 3        yes
# 4        yes
# 5         no
# 6        yes
# 7         no
# 8        yes
# 9        yes
# 10       yes
# 11       yes
# 12       yes
# 13        no

# %%
COLUMNS = 1
compare_df = pd.concat([y,predict_df],axis=COLUMNS)
compare_df
# Out:
#    play predicted
# 0    no        no
# 1    no        no
# 2   yes       yes
# 3   yes       yes
# 4   yes       yes
# 5    no        no
# 6   yes       yes
# 7    no        no
# 8   yes       yes
# 9   yes       yes
# 10  yes       yes
# 11  yes       yes
# 12  yes       yes
# 13   no        no

# %%
print("The accuracy of our model is: {}%"
      .format(metrics.accuracy_score(y, predict_df)*100))
# Out:
# The accuracy of our model is: 100.0%

# %%
import pandas as pd # data science library
url = "https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/tennis.csv" # the URL
data = pd.read_csv(url)


from sklearn import tree


from sklearn.metrics import accuracy_score
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no
